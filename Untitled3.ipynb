# %%
import numpy as np
import pandas as pd
import os 
os.getcwd()
# Out:
# 'C:\\Users\\E682'

# %%
data=pd.read_excel('Coeur.xlsx')
data
# Out:
#      AGE   SEXE  TDT    PAR  CHOLESTEROL  GAJ     ECG  FCMAX ANGINE  \
# 0     40  homme   AA  140.0        289.0    0  Normal    172    Non
# 1     49  femme  DNA  160.0        180.0    0  Normal    156    Non
# 2     37  homme   AA  130.0        283.0    0      ST     98    Non
# 3     48  femme  ASY  138.0        214.0    0  Normal    108    Oui
# 4     54  homme  DNA  150.0        195.0    0  Normal    122    Non
# ..   ...    ...  ...    ...          ...  ...     ...    ...    ...
# 913   45  homme   AT    NaN        264.0    0  Normal    132    Non
# 914   68  homme  ASY    NaN        193.0    1  Normal    141    Non
# 915   57  homme  ASY    NaN        131.0    0  Normal    115    Oui
# 916   57  femme   AA    NaN        236.0    0     LVH    174    Non
# 917   38  homme  DNA    NaN        175.0    0  Normal    173    Non
#
#      DEPRESSION      PENTE  CŒUR
# 0           0.0  Ascendant     0
# 1           1.0       Plat     1
# 2           0.0  Ascendant     0
# ...

# %%
df=data
data
# Out:
#      AGE   SEXE  TDT    PAR  CHOLESTEROL  GAJ     ECG  FCMAX ANGINE  \
# 0     40  homme   AA  140.0        289.0    0  Normal    172    Non
# 1     49  femme  DNA  160.0        180.0    0  Normal    156    Non
# 2     37  homme   AA  130.0        283.0    0      ST     98    Non
# 3     48  femme  ASY  138.0        214.0    0  Normal    108    Oui
# 4     54  homme  DNA  150.0        195.0    0  Normal    122    Non
# ..   ...    ...  ...    ...          ...  ...     ...    ...    ...
# 913   45  homme   AT    NaN        264.0    0  Normal    132    Non
# 914   68  homme  ASY    NaN        193.0    1  Normal    141    Non
# 915   57  homme  ASY    NaN        131.0    0  Normal    115    Oui
# 916   57  femme   AA    NaN        236.0    0     LVH    174    Non
# 917   38  homme  DNA    NaN        175.0    0  Normal    173    Non
#
#      DEPRESSION      PENTE  CŒUR
# 0           0.0  Ascendant     0
# 1           1.0       Plat     1
# 2           0.0  Ascendant     0
# ...

# %%
def malist(x):
    list=pd.DataFrame(x.dtypes)
    return list

malist(df)
# Out:
#                    0
# AGE            int64
# SEXE          object
# TDT           object
# PAR          float64
# CHOLESTEROL  float64
# GAJ            int64
# ECG           object
# FCMAX          int64
# ANGINE        object
# DEPRESSION   float64
# PENTE         object
# CŒUR           int64

# %%
def recode(datam,homme='homme',femme='femme'):
    return datam["SEXE"].replace({'homme':homme,'femme':femme}, inplace=True)
recode(df, homme = 0, femme = 1)
df
# Out:
#      AGE  SEXE  TDT    PAR  CHOLESTEROL  GAJ    ECG  FCMAX ANGINE  DEPRESSION  \
# 0     40     0   AA  140.0        289.0    0   norm    172     no         0.0
# 1     49     1  DNA  160.0        180.0    0   norm    156     no         1.0
# 2     37     0   AA  130.0        283.0    0  salut     98     no         0.0
# 3     48     1  ASY  138.0        214.0    0   norm    108    yes         1.5
# 4     54     0  DNA  150.0        195.0    0   norm    122     no         0.0
# ..   ...   ...  ...    ...          ...  ...    ...    ...    ...         ...
# 913   45     0   AT    NaN        264.0    0   norm    132     no         1.2
# 914   68     0  ASY    NaN        193.0    1   norm    141     no         3.4
# 915   57     0  ASY    NaN        131.0    0   norm    115    yes         1.2
# 916   57     1   AA    NaN        236.0    0    LVH    174     no         0.0
# 917   38     0  DNA    NaN        175.0    0   norm    173     no         0.0
#
#          PENTE  CŒUR
# ...

# %%
def recode_m(**col):
    v = col.pop(list(col)[0])
    d = {i:j for i, j in col.items()}
    return v.replace(d, inplace=True)
recode_m(v = df, Normal = "norm", Oui = "yes", Non = "no", ST = "salut")
df
# Out:
#      AGE  SEXE  TDT    PAR  CHOLESTEROL  GAJ    ECG  FCMAX ANGINE  DEPRESSION  \
# 0     40     0   AA  140.0        289.0    0   norm    172     no         0.0
# 1     49     1  DNA  160.0        180.0    0   norm    156     no         1.0
# 2     37     0   AA  130.0        283.0    0  salut     98     no         0.0
# 3     48     1  ASY  138.0        214.0    0   norm    108    yes         1.5
# 4     54     0  DNA  150.0        195.0    0   norm    122     no         0.0
# ..   ...   ...  ...    ...          ...  ...    ...    ...    ...         ...
# 913   45     0   AT    NaN        264.0    0   norm    132     no         1.2
# 914   68     0  ASY    NaN        193.0    1   norm    141     no         3.4
# 915   57     0  ASY    NaN        131.0    0   norm    115    yes         1.2
# 916   57     1   AA    NaN        236.0    0    LVH    174     no         0.0
# 917   38     0  DNA    NaN        175.0    0   norm    173     no         0.0
#
#          PENTE  CŒUR
# ...

# %%
df_2=data.groupby(["SEXE"]).get_group("homme").groupby(["CŒUR"]).get_group(1)
df_2
# Out:
#      AGE   SEXE  TDT    PAR  CHOLESTEROL  GAJ     ECG  FCMAX ANGINE  \
# 8     37  homme  ASY  140.0        207.0    0  Normal    130    Oui
# 11    58  homme   AA  136.0        164.0    0      ST     99    Oui
# 13    49  homme  ASY  140.0        234.0    0  Normal    140    Oui
# 16    38  homme  ASY  110.0        196.0    0  Normal    166    Non
# 18    60  homme  ASY  100.0        248.0    0     NaN    125    Non
# ..   ...    ...  ...    ...          ...  ...     ...    ...    ...
# 908   63  homme  ASY  140.0        187.0    0     LVH    144    Oui
# 911   59  homme  ASY  164.0        176.0    1     LVH     90    Non
# 913   45  homme   AT    NaN        264.0    0  Normal    132    Non
# 914   68  homme  ASY    NaN        193.0    1  Normal    141    Non
# 915   57  homme  ASY    NaN        131.0    0  Normal    115    Oui
#
#      DEPRESSION      PENTE  CŒUR
# 8           1.5       Plat     1
# 11          2.0       Plat     1
# 13          1.0       Plat     1
# ...

# %%
pd.crosstab(data.SEXE,data.CŒUR)
# Out:
# CŒUR     0    1
# SEXE
# femme  143   50
# homme  267  458

# %%
data["AGE"].hist()
# Out:
# Matplotlib is building the font cache; this may take a moment.
# <AxesSubplot:>

# %%
data.plot.scatter("AGE","DEPRESSION")
# Out:
# <AxesSubplot:xlabel='AGE', ylabel='DEPRESSION'>

# %%
val_qual=(data.dtypes==object)
val_qual
# Out:
# AGE            False
# SEXE            True
# TDT             True
# PAR            False
# CHOLESTEROL    False
# GAJ            False
# ECG             True
# FCMAX          False
# ANGINE          True
# DEPRESSION     False
# PENTE           True
# CŒUR           False
# dtype: bool

# %%
#val_quant=data.loc[data.dtypes==object,[0,1,2,3]]
#val_quant
data.loc[0,1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\Nouveau dossier (2)\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-c125aa7c1b1e> in <module>
# ...
